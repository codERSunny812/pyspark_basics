# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('df').master('local[2]').getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/03 22:19:32 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/02/03 22:19:34 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/02/03 22:19:34 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://sunny:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>df</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.csv("/home/hadoop/Downloads/custs_without_header.csv",header=True)

# %%
df.show(3)
# Out:
# +----------+----------+---------+---+-----------+
# |custmer_id|First_name|Last_name|age| Occupation|
# +----------+----------+---------+---+-----------+
# |   4000001|  Kristina|    Chung| 55|      Pilot|
# |   4000002|     Paige|     Chen| 74|    Teacher|
# |   4000003|    Sherri|   Melton| 34|Firefighter|
# +----------+----------+---------+---+-----------+
# only showing top 3 rows
